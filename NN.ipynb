# %%
import numpy as np

# %%
x = np.array([0,0],
             [0,1],
             [1,0],
             [1,1],dtype=np.float32) ##stores 4 bytes per element 

y = np.array([[0],[1],[1],[0]], dtype=np.float32)
